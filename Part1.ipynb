# %% [markdown]
# <a href="https://colab.research.google.com/github/ionutpopa/image-duplicator-remover-api/blob/main/Perfectt%20aproape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U gdown

# %%
# !gdown --id 1G_g3NEcluW9iKbWY6BiCMcSo0eLxCG0z
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1G_g3NEcluW9iKbWY6BiCMcSo0eLxCG0z
# From (redirected): https://drive.google.com/uc?id=1G_g3NEcluW9iKbWY6BiCMcSo0eLxCG0z&confirm=t&uuid=76f11a5a-8791-40a2-9646-940738ba7b41
# To: /content/fabric.tar.gz
# 100% 13.0G/13.0G [00:59<00:00, 217MB/s]

# %%
# !rm -rf fabrics_dataset

# %%
# !tar -xvzf fabric.tar.gz -C fabrics_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
# ./fabric/test/chiffon/289725_imaterial.jpeg
# ./fabric/test/chiffon/289927_imaterial.jpeg
# ./fabric/test/chiffon/290071_imaterial.jpeg
# ./fabric/test/chiffon/290113_imaterial.jpeg
# ./fabric/test/chiffon/290367_imaterial.jpeg
# ./fabric/test/chiffon/290458_imaterial.jpeg
# ./fabric/test/chiffon/290703_imaterial.jpeg
# ./fabric/test/chiffon/291067_imaterial.jpeg
# ./fabric/test/chiffon/291235_imaterial.jpeg
# ./fabric/test/chiffon/291463_imaterial.jpeg
# ./fabric/test/chiffon/2918_imaterial.jpeg
# ./fabric/test/chiffon/291922_imaterial.jpeg
# ./fabric/test/chiffon/291998_imaterial.jpeg
# ./fabric/test/chiffon/29256_imaterial.jpeg
# ./fabric/test/chiffon/292922_imaterial.jpeg
# ./fabric/test/chiffon/2930_imaterial.jpeg
# ./fabric/test/chiffon/293250_imaterial.jpeg
# ./fabric/test/chiffon/293260_imaterial.jpeg
# ./fabric/test/chiffon/293773_imaterial.jpeg
# ./fabric/test/chiffon/293845_imaterial.jpeg
# ...

# %%
# !python cleaner.py
# Out:
# Deleting 'serge' with only 528 images.
# Deleting 'neoprene' with only 184 images.
# Deleting 'plush' with only 209 images.
# Deleting 'canvas' with only 12 images.
# Deleting 'twill' with only 31 images.
# Deleting 'lawn' with only 928 images.
# Deleting 'taffeta' with only 810 images.
# Deleting 'vinyl' with only 202 images.
# Deleting 'chenille' with only 809 images.

# %%
# !pip install -q transformers pillow tqdm

# %% [markdown]
# 18 clase au ramas

# %%
# !python annotator.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing 592425_imaterial.jpeg in denim
# Processing 768751_imaterial.jpeg in denim
# Processing 215724_imaterial.jpeg in denim
# Processing 781235_imaterial.jpeg in denim
# Processing 406003_imaterial.jpeg in denim
# Processing 687127_imaterial.jpeg in denim
# Processing g1808883_01.jpg in denim
# Processing akk97755_indigo_xl.jpg in denim
# Processing 681340_imaterial.jpeg in denim
# Processing 31665_imaterial.jpeg in denim
# Processing 36108_imaterial.jpeg in denim
# Processing 309192_imaterial.jpeg in denim
# Processing 853068_imaterial.jpeg in denim
# Processing 954179_imaterial.jpeg in denim
# Processing 949719_imaterial.jpeg in denim
# Processing 686341_imaterial.jpeg in denim
# Processing 8197082405_2_1_1.jpg in denim
# Processing 593861_imaterial.jpeg in denim
# Processing 715798_imaterial.jpeg in denim
# ...

# %%
# !python demerger.py
# Out:
# 100% 20928/20928 [00:29<00:00, 698.49it/s]

# %%
# !python train.py --task fabric_class
# Out:
# 📦 Loading dataset for: fabric_class
# 🧠 Training ResNet50 for fabric_class with 18 classes
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 208MB/s]
# Epoch 1: 100% 524/524 [02:58<00:00,  2.94it/s]
# Epoch 1, Loss: 1.8437
# ...

# %%
# !python train.py --task material_weight
# Out:
# 📦 Loading dataset for: material_weight
# 🧠 Training ResNet50 for material_weight with 3 classes
# Epoch 1: 100% 523/523 [02:59<00:00,  2.91it/s]
# Epoch 1, Loss: 0.5569
# Epoch 2: 100% 523/523 [02:56<00:00,  2.97it/s]
# Epoch 2, Loss: 0.3603
# Epoch 3: 100% 523/523 [02:57<00:00,  2.95it/s]
# Epoch 3, Loss: 0.1932
# Epoch 4: 100% 523/523 [02:57<00:00,  2.95it/s]
# Epoch 4, Loss: 0.1031
# Epoch 5: 100% 523/523 [02:56<00:00,  2.96it/s]
# Epoch 5, Loss: 0.0750
# 🧪 Evaluating model on validation set...
# ✅ Classification report saved to material_weight_report.txt
# ✅ Confusion matrix saved to material_weight_confusion_matrix.png
# ✅ Model saved to material_weight_resnet50.pth

# %%
# !python train.py --task finish
# Out:
# 📦 Loading dataset for: finish
# 🧠 Training ResNet50 for finish with 5 classes
# Epoch 1: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 1, Loss: 1.0418
# Epoch 2: 100% 523/523 [02:52<00:00,  3.03it/s]
# Epoch 2, Loss: 0.6865
# Epoch 3: 100% 523/523 [02:52<00:00,  3.03it/s]
# Epoch 3, Loss: 0.3569
# Epoch 4: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 4, Loss: 0.1951
# Epoch 5: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 5, Loss: 0.1230
# 🧪 Evaluating model on validation set...
# ✅ Classification report saved to finish_report.txt
# ✅ Confusion matrix saved to finish_confusion_matrix.png
# ✅ Model saved to finish_resnet50.pth

# %% [markdown]
# Acum rulam cu 10 epochs si resume

# %%
# !python train.py --task fabric_class --resume_from fabric_class_resnet50.pth
