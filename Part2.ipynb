# %% [markdown]
# <a href="https://colab.research.google.com/github/ionutpopa/image-duplicator-remover-api/blob/main/Final%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown --id 1v3sWvreo4T5CU0PyKXgcHI_NODIYSlym
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1v3sWvreo4T5CU0PyKXgcHI_NODIYSlym
# From (redirected): https://drive.google.com/uc?id=1v3sWvreo4T5CU0PyKXgcHI_NODIYSlym&confirm=t&uuid=a00ceeaa-d568-435c-a179-52087866ce31
# To: /content/fabric.tar.gz
# 100% 13.0G/13.0G [02:10<00:00, 99.4MB/s]

# %%
# !tar -xvzf fabric.tar.gz -C fabrics_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
# ./fabric/test/chiffon/289725_imaterial.jpeg
# ./fabric/test/chiffon/289927_imaterial.jpeg
# ./fabric/test/chiffon/290071_imaterial.jpeg
# ./fabric/test/chiffon/290113_imaterial.jpeg
# ./fabric/test/chiffon/290367_imaterial.jpeg
# ./fabric/test/chiffon/290458_imaterial.jpeg
# ./fabric/test/chiffon/290703_imaterial.jpeg
# ./fabric/test/chiffon/291067_imaterial.jpeg
# ./fabric/test/chiffon/291235_imaterial.jpeg
# ./fabric/test/chiffon/291463_imaterial.jpeg
# ./fabric/test/chiffon/2918_imaterial.jpeg
# ./fabric/test/chiffon/291922_imaterial.jpeg
# ./fabric/test/chiffon/291998_imaterial.jpeg
# ./fabric/test/chiffon/29256_imaterial.jpeg
# ./fabric/test/chiffon/292922_imaterial.jpeg
# ./fabric/test/chiffon/2930_imaterial.jpeg
# ./fabric/test/chiffon/293250_imaterial.jpeg
# ./fabric/test/chiffon/293260_imaterial.jpeg
# ./fabric/test/chiffon/293773_imaterial.jpeg
# ./fabric/test/chiffon/293845_imaterial.jpeg
# ...

# %%
# !pip install -q transformers pillow tqdm

# %%
# !python cleaner.py
# Out:
# Deleting 'serge' with only 528 images.
# Deleting 'neoprene' with only 184 images.
# Deleting 'plush' with only 209 images.
# Deleting 'canvas' with only 12 images.
# Deleting 'twill' with only 31 images.
# Deleting 'lawn' with only 928 images.
# Deleting 'taffeta' with only 810 images.
# Deleting 'vinyl' with only 202 images.
# Deleting 'chenille' with only 809 images.

# %%
# !python demerger.py
# Out:
#  59% 12389/20928 [00:20<01:44, 81.85it/s] Failed to copy fabrics_dataset/fabric/train/gingham-primary-gingham-dress-short-1.jpg: [Errno 2] No such file or directory: 'fabrics_dataset/fabric/train/gingham-primary-gingham-dress-short-1.jpg'
# Failed to copy fabrics_dataset/fabric/train/gingham-primary-gingham-dress-short-1.jpg: [Errno 2] No such file or directory: 'fabrics_dataset/fabric/train/gingham-primary-gingham-dress-short-1.jpg'
# Failed to copy fabrics_dataset/fabric/train/gingham-primary-gingham-dress-short-1.jpg: [Errno 2] No such file or directory: 'fabrics_dataset/fabric/train/gingham-primary-gingham-dress-short-1.jpg'
# 100% 20928/20928 [00:30<00:00, 684.83it/s]

# %%
# !python train.py --task fabric_class --epochs 10 --resume_from 5_epochs_fabric_class_resnet50.pth
# Out:
# 📦 Loading dataset for: fabric_class
# 🧠 Training ResNet50 for fabric_class with 18 classes
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 171MB/s]
# 🔁 Loaded model weights from 5_epochs_fabric_class_resnet50.pth
# Epoch 1: 100% 524/524 [02:57<00:00,  2.95it/s]
# Epoch 1, Loss: 0.5818
# Epoch 2: 100% 524/524 [02:54<00:00,  3.00it/s]
# Epoch 2, Loss: 0.2363
# Epoch 3: 100% 524/524 [02:54<00:00,  3.00it/s]
# Epoch 3, Loss: 0.1736
# Epoch 4: 100% 524/524 [02:54<00:00,  3.00it/s]
# Epoch 4, Loss: 0.1711
# Epoch 5: 100% 524/524 [02:54<00:00,  3.00it/s]
# Epoch 5, Loss: 0.1653
# Epoch 6: 100% 524/524 [02:55<00:00,  2.99it/s]
# Epoch 6, Loss: 0.1634
# Epoch 7: 100% 524/524 [02:55<00:00,  2.99it/s]
# Epoch 7, Loss: 0.1122
# Epoch 8: 100% 524/524 [02:55<00:00,  2.99it/s]
# Epoch 8, Loss: 0.0917
# Epoch 9: 100% 524/524 [02:55<00:00,  2.98it/s]
# Epoch 9, Loss: 0.1282
# ...

# %%
# !python train.py --task material_weight --epochs 10 --resume_from 5_epochs_material_weight_resnet50.pth
# Out:
# 📦 Loading dataset for: material_weight
# 🧠 Training ResNet50 for material_weight with 3 classes
# 🔁 Loaded model weights from 5_epochs_material_weight_resnet50.pth
# Epoch 1: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 1, Loss: 0.2016
# Epoch 2: 100% 523/523 [02:52<00:00,  3.03it/s]
# Epoch 2, Loss: 0.0659
# Epoch 3: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 3, Loss: 0.0483
# Epoch 4: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 4, Loss: 0.0511
# Epoch 5: 100% 523/523 [02:55<00:00,  2.98it/s]
# Epoch 5, Loss: 0.0536
# Epoch 6: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 6, Loss: 0.0456
# Epoch 7: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 7, Loss: 0.0395
# Epoch 8: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 8, Loss: 0.0327
# Epoch 9: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 9, Loss: 0.0315
# Epoch 10: 100% 523/523 [02:55<00:00,  2.99it/s]
# Epoch 10, Loss: 0.0394
# 🧪 Evaluating model on validation set...
# ...

# %%
# !python train.py --task finish --epochs 10 --resume_from 5_epochs_finish_resnet50.pth
# Out:
# 📦 Loading dataset for: finish
# 🧠 Training ResNet50 for finish with 5 classes
# 🔁 Loaded model weights from 5_epochs_finish_resnet50.pth
# Epoch 1: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 1, Loss: 0.3307
# Epoch 2: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 2, Loss: 0.1043
# Epoch 3: 100% 523/523 [02:54<00:00,  3.00it/s]
# Epoch 3, Loss: 0.0930
# Epoch 4: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 4, Loss: 0.0885
# Epoch 5: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 5, Loss: 0.0726
# Epoch 6: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 6, Loss: 0.0606
# Epoch 7: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 7, Loss: 0.0685
# Epoch 8: 100% 523/523 [02:53<00:00,  3.01it/s]
# Epoch 8, Loss: 0.0630
# Epoch 9: 100% 523/523 [02:54<00:00,  2.99it/s]
# Epoch 9, Loss: 0.0553
# Epoch 10: 100% 523/523 [02:54<00:00,  2.99it/s]
# Epoch 10, Loss: 0.0575
# 🧪 Evaluating model on validation set...
# ✅ Classification report saved to finish_report.txt
# ...
